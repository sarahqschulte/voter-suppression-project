# %%
import pandas as pd
import json 
import datetime as dt

# %% [markdown]
# These csv files were downloaded on October 8th, 2020 from http://www.electproject.org/ The values for the 2020 General Election were the amounts that were available as of this date.

# %% [markdown]
# # Primary Election 2016

# %% [markdown]
# ## Importing the data

# %%
Primary2016 = pd.read_csv("2016PrimaryElection2.csv")
# Primary2016

# %%
NewHeader = Primary2016.iloc[0]
# NewHeader

# %%
Primary2016 = Primary2016[1:]
# Primary2016

# %%
Primary2016.columns = NewHeader
Primary2016
# Out:
# 0      Date                                              State Election Type  \
# 1    3/1/16                                            Alabama       Primary
# 2   3/26/16                                             Alaska        Caucus
# 3   3/22/16                                            Arizona       Primary
# 4       NaN                                           Arkansas       Primary
# 5    6/7/16                                         California       Primary
# 6       NaN                                           Colorado        Caucus
# 7   4/26/16                                        Connecticut       Primary
# 8       NaN                                           Delaware       Primary
# 9   3/15/16                                            Florida       Primary
# 10      NaN                                            Georgia       Primary
# 11      NaN                                             Hawaii        Caucus
# ...

# %% [markdown]
# ## Cleaning the Data

# %%
# # import datetime as dt 
# import numpy as np

# %% [markdown]
# Attempting to get rid of Null values possibly, will confer with the team if this is something that will benefit the migration to MySQL.

# %%
# Primary2016["Date"].replace("NaN",0)
# Primary2016

# %%
# Primary2016["Date"] = pd.to_datetime(Primary2016['Date'], format='%m/%d/%Y')
# Primary2016

# %%
Columns = Primary2016[['State','Voting-Eligible Population (VEP)','Voting-Age Population (VAP)']]
Primary2016Drop = Columns.copy()
Primary2016Drop
# Out:
# 0                                               State  \
# 1                                             Alabama
# 2                                              Alaska
# 3                                             Arizona
# 4                                            Arkansas
# 5                                          California
# 6                                            Colorado
# 7                                         Connecticut
# 8                                            Delaware
# 9                                             Florida
# 10                                            Georgia
# 11                                             Hawaii
# 12                                              Idaho
# 13                                           Illinois
# 14                                            Indiana
# 15                                               Iowa
# 16                                             Kansas
# ...

# %%
Primary2016Drop['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming',
#        'Wyoming (canceled for March 12 county conventions)',
#        'District of Columbia'], dtype=object)

# %% [markdown]
# # As of 10/12 by Sarah @ noonish

# %% [markdown]
# As of now, I have duplicate values for the states Wyoming, Washington, DC and North Dakota. I am still trying to figure what to do... The original CSV has duplicate values for VEP and VAP depending on the source of the data. There are conflicting reports on the total number of VEP values and VAP values depending on caucus/primary. In one case: North Dakota GOP caucus reported 575,846 VEP but the Democratic caucus reports 578,789; a difference of 3,000+ votes is not a small residual value and additional research must be done to account for these VEP/VAP values.

# %% [markdown]
# # General Election 2016

# %%
General2016 = pd.read_csv("2016GeneralElection.csv")

# %%
General2016.head()
# Out:
#                                                 State  \
# 0                                                 NaN
# 1                                       United States
# 2                                             Alabama
# 3                                              Alaska
# 4                                             Arizona
# 5                                            Arkansas
# 6                                          California
# 7                                            Colorado
# 8                                         Connecticut
# 9                                            Delaware
# 10                               District of Columbia
# 11                                            Florida
# 12                                            Georgia
# 13                                             Hawaii
# 14                                              Idaho
# 15                                           Illinois
# ...

# %%
Midterm2018 = pd.read_csv("2018GeneralElection.csv")

# %%
Midterm2018.head()
# Out:
#                    State                                         Unnamed: 1  \
# 0                    NaN  Estimated or Actual 2018 Total Ballots Counted...
# 1          United States                                              50.0%
# 2                Alabama                                              47.0%
# 3                 Alaska                                              54.8%
# 4                Arizona                                              47.4%
# 5               Arkansas                                              41.3%
# 6             California                                              49.3%
# 7               Colorado                                              61.4%
# 8            Connecticut                                              54.8%
# 9               Delaware                                              51.2%
# 10  District of Columbia                                              43.7%
# ...

# %%
Primary2020 = pd.read_csv("2020PrimaryElection.csv")

# %%
Primary2020.head()
# Out:
#    Unnamed: 0      Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0        Date           State  Election Type      Party
# 1    2/3/2020            Iowa         Caucus        D&R
# 2   2/11/2020   New Hampshire        Primary        D&R
# 3   2/22/2020          Nevada         Caucus          D
# 4   2/29/2020  South Carolina        Primary          D
# ..        ...             ...            ...        ...
# 62        NaN        Oklahoma  State Primary        D&R
# 63        NaN            Utah  State Primary          c
# 64  7/14/2020         Alabama  State Primary          R
# 65   8/8/2020          Hawaii  State Primary        D&R
# 66  8/18/2020         Florida  State Primary        D&R
#
#                  Turnout Rate                      Denominators  \
# 0   VEP Total Ballots Counted  Voting-Eligible Population (VEP)
# 1                        9.1%                         2,305,858
# 2                       42.4%                         1,077,914
# ...

# %%
General2020inc = pd.read_csv("2020GeneralElection108.csv")

# %%
General2020inc.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-867eb8280d0f> in <module>
# ----> 1 General2020inc.head()
#
# NameError: name 'General2020inc' is not defined
